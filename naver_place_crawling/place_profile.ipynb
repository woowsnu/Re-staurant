# %%
import requests
from master import headers
import json
import pandas as pd

url = "https://pcmap-api.place.naver.com/graphql"

# headers = {'User-Agent' : '개인 user-agent', 'Content-Type': 'application/json', 'accept': '*/*', 'accept-encoding': 'gzip, deflate, br', 'accept-language': 'ko'}
headers['Content-Type'] = "application/json"
headers['accept'] = '*/*'
headers['accept-encoding'] = 'gzip, deflate, br'
headers['accept-language'] = 'ko'

# %%
r.json().keys()
# Out:
# dict_keys(['id', 'isSite', 'name', 'type', 'rCode', 'x', 'y', 'posExact', 'address', 'fullAddress', 'addressAbbr', 'roadAddr', 'fullRoadAddress', 'phone', 'isCallLink', 'description', 'way', 'keywords', 'hasNaverTalktalkUrl', 'naverTalktalkUrl', 'adult', 'endPageUrl', 'mobileEndPageUrl', 'urlList', 'ktCallMd', 'ppc', 'images', 'imageURL', 'imageModDate', 'displayCategory', 'category', 'categories', 'categoryPaths', 'bizHour', 'bizhourInfo', 'options', 'menus', 'menuImages', 'previewImages', 'streetPanorama', 'skyPanorama', 'insidePanorama', 'interiorPanorama', 'indoorPanorama', 'entranceCoords', 'theme', 'hasNaverBooking', 'naverBookingUrl', 'naverbookingId', 'petrolInfo', 'michelinGuide', 'broadcastInfo', 'marker', 'markerSelected', 'datalab', 'reviewCount', 'dynamicData', 'markerLabel', 'isParkingSupported'])

# %%
r.json().values()

for k,v in r.json().items():
    print(f"key: {k}, value: {v} \n")

# %%
import pyproj
epsg3857 = pyproj.Proj(init='epsg:3857')
wgs84 = pyproj.Proj(init='epsg:4326')
pyproj.transform(epsg3857,wgs84,14177093.3603591,4349800.2574546)
# Out:
# c:\Anaconda\envs\study\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Anaconda\envs\study\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\강건\AppData\Local\Temp/ipykernel_5456/3136991266.py:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   pyproj.transform(epsg3857,wgs84,14177093.3603591,4349800.2574546)
# (127.35499649999966, 36.35659770000021)

# %%
import time
places = {}
for j in range(1,30):
    r = requests.get(url=f'https://map.naver.com/v5/api/search?caller=pcweb&query=%EC%9D%8C%EC%8B%9D%EC%A0%90&type=all&searchCoord=126.3219378;33.3847245&page={j}&displayCount=100&isPlaceRecommendationReplace=true&lang=ko', headers=headers)
    if 'error' in r.json().keys():
        print(r.json()['error']['displayMsg'])
        break
    places[j] = r.json()['result']['place']['list']
    time.sleep(0.5)
places
# Out:
# 잘못된 요청입니다.
# {1: [{'index': '0',
#    'rank': '1',
#    'id': '1633977299',
#    'name': '조식',
#    'tel': '',
#    'isCallLink': False,
#    'virtualTel': '',
#    'ppc': '0',
#    'category': ['음식점', '브런치'],
#    'categoryPath': [['220036', '220044', '220133', '220932']],
#    'address': '제주특별자치도 제주시 애월읍 어음리 3459-1',
#    'roadAddress': '제주특별자치도 제주시 애월읍 어림비로 272',
#    'abbrAddress': '어음리 3459-1',
#    'shortAddress': ['제주 제주시 애월읍', '어림비로 272'],
#    'display': '조식',
#    'telDisplay': '',
#    'context': [],
#    'reviewCount': 180,
#    'ktCallMd': 'bcea864ca0011e1b6468c2cd50f5bd2f',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20211208_235/1638933340248ANp74_JPEG/0558DD38-988C-4A8E-8B60-633C60C1C1AC.jpeg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.3332056',
#    'y': '33.4105799',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'KeTNJyUzYwZYTdoAvMYu0A==',
#     'pan': '-92.83',
#     'tilt': '10.00',
#     'lng': '126.3333227',
#     'lat': '33.4105856',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'http://instagram.com/josik.aewol',
#    'description': '',
#    'entranceCoords': None,
#    'isPollingPlace': False,
#    'bizhourInfo': '토요일 10:00~17:00 매주 화요일 휴무, 매월 마지막주 화/수 이틀 휴무 | 금요일 10:00~17:00 매주 화요일 휴무, 매월 마지막주 화/수 이틀 휴무 | 목요일 10:00~17:00 매주 화요일 휴무, 매월 마지막주 화/수 이틀 휴무 | 수요일 10:00~17:00 매주 화요일 휴무, 매월 마지막주 화/수 이틀 휴무 | 일요일 10:00~17:00 매주 화요일 휴무, 매월 마지막주 화/수 이틀 휴무 | 월요일 10:00~17:00 매주 화요일 휴무, 매월 마지막주 화/수 이틀 휴무',
#    'menuInfo': '커피 7,000 | 조식플레이트 19,000 | 착즙쥬스 8,000 | 프렌치토스트 15,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3062.01',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '1',
#    'rank': '2',
#    'id': '1439356450',
#    'name': '어음밥집',
#    'tel': '064-799-0788',
#    'isCallLink': False,
#    'virtualTel': '0507-1441-0791',
#    'ppc': '1',
#    'category': ['음식점', '한식'],
#    'categoryPath': [['220036', '220037', '220053'], ['1004760', '1004452']],
#    'address': '제주특별자치도 제주시 애월읍 어음리 2949-4',
#    'roadAddress': '제주특별자치도 제주시 애월읍 어림비로 393-1',
#    'abbrAddress': '어음리 2949-4',
#    'shortAddress': ['제주 제주시 애월읍', '어림비로 393-1'],
#    'display': '어음밥집',
#    'telDisplay': '064-799-0788',
#    'context': [],
#    'reviewCount': 5,
#    'ktCallMd': '5a48d3dcb7c915742efb98ee3c0598e5',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20220611_190/1654948765670RDzeL_JPEG/20210227_105441.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.3392341',
#    'y': '33.4019981',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'SK7TgtZn2NzFOq/86MqsZA==',
#     'pan': '13.94',
#     'tilt': '10.00',
#     'lng': '126.3392037',
#     'lat': '33.4018756',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': '',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.339219, 'y': 33.401936}],
#     'walk': [{'rep': True, 'x': 126.339219, 'y': 33.401936}]},
#    'isPollingPlace': False,
#    'bizhourInfo': None,
#    'menuInfo': None,
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '0',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '2505.69',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '2',
#    'rank': '3',
#    'id': '1449299326',
#    'name': '어음분교1963',
#    'tel': '010-4752-2919',
#    'isCallLink': False,
#    'virtualTel': '0507-1306-2919',
#    'ppc': '1',
#    'category': ['음식점', '카페,디저트'],
#    'categoryPath': [['220036', '220052', '220563'],
#     ['1004760', '1004380', '1004431']],
#    'address': '제주특별자치도 제주시 애월읍 어음리 2922 어음분교1963',
#    'roadAddress': '제주특별자치도 제주시 애월읍 어림비로 376 어음분교1963',
#    'abbrAddress': '어음리 2922 어음분교1963',
#    'shortAddress': ['제주 제주시 애월읍', '어림비로 376', '어음분교1963'],
#    'display': '어음분교1963',
#    'telDisplay': '010-4752-2919',
#    'context': [],
#    'reviewCount': 92,
#    'ktCallMd': 'b224063cfdd8ad25de0382954d57146c',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20211027_198/1635313148707aX7Fc_JPEG/H2YRqZ9N5eBid_V2vVl2_qw3.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.3384616',
#    'y': '33.4032743',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': '5JEeBUQXCqmd/9owAUuKlQ==',
#     'pan': '-111.02',
#     'tilt': '-13.63',
#     'lng': '126.3387049',
#     'lat': '33.4030632',
#     'fov': '90'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': '',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.338634, 'y': 33.402975}],
#     'walk': [{'rep': True, 'x': 126.338634, 'y': 33.402975}]},
#    'isPollingPlace': False,
#    'bizhourInfo': '일요일 10:00~18:00 | 월요일 10:00~18:00 | 토요일 10:00~18:00 | 금요일 10:00~18:00 | 목요일 10:00~18:00 | 수요일 10:00~18:00 | 화요일 10:00~18:00',
#    'menuInfo': '딸기라떼 5,000 | 감귤요거트 스무디 5,000 | 한라봉주스 6,000 | 한라봉에이드 5,000 | 청귤에이드 5,000 | 개역(미숫가루) 5,000 | 어묵우동 6,000 | 햄/새우볶음밥 7,000 | 오메기떡 3,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': True,
#    'naverBookingUrl': 'https://booking.naver.com/booking/3/bizes/502527',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': True,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': '[기획전] N예약시 숙박 20% 할인'},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': True,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '2572.77',
#    'marker': 'nres://marker/00079-00037',
#    'markerSelected': 'nres://marker/00079-00200',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '3',
#    'rank': '4',
#    'id': '1051333889',
#    'name': '한라종합식품',
#    'tel': '010-9108-7003',
#    'isCallLink': False,
#    'virtualTel': '0507-1383-7027',
#    'ppc': '1',
#    'category': ['카페,디저트', '떡카페'],
#    'categoryPath': [['220036', '220052', '220589', '230488'],
#     ['1004760', '1004452']],
#    'address': '제주특별자치도 제주시 한림읍 금악리 625-2',
#    'roadAddress': '제주특별자치도 제주시 한림읍 가린내길 114',
#    'abbrAddress': '금악리 625-2',
#    'shortAddress': ['제주 제주시 한림읍', '가린내길 114'],
#    'display': '한라종합식품',
#    'telDisplay': '010-9108-7003',
#    'context': [],
#    'reviewCount': 1,
#    'ktCallMd': 'aecb8778d6edf15fc079465ff7462910',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20210406_232/16176907974867KbtM_JPEG/mCojozZbBueh9q7nsOh2Ohpl.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.3184298',
#    'y': '33.3648949',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'vI8OJMifIzX5tuK00el8/Q==',
#     'pan': '77.70',
#     'tilt': '-0.81',
#     'lng': '126.3176695',
#     'lat': '33.3653554',
#     'fov': '80'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'http://www.hallafd.com',
#    'description': '',
#    'entranceCoords': None,
#    'isPollingPlace': False,
#    'bizhourInfo': None,
#    'menuInfo': '오메기떡 1,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '2230.81',
#    'marker': 'nres://marker/00079-00037',
#    'markerSelected': 'nres://marker/00079-00200',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '4',
#    'rank': '5',
#    'id': '933405444',
#    'name': '녹근로33',
#    'tel': '064-799-3340',
#    'isCallLink': False,
#    'virtualTel': '',
#    'ppc': '1',
#    'category': ['일식', '돈가스'],
#    'categoryPath': [['220036', '220038', '220082', '220812'],
#     ['1004760', '1004380', '1002043']],
#    'address': '제주특별자치도 제주시 애월읍 봉성리 3228-2',
#    'roadAddress': '제주특별자치도 제주시 애월읍 녹근로 33',
#    'abbrAddress': '봉성리 3228-2',
#    'shortAddress': ['제주 제주시 애월읍', '녹근로 33'],
#    'display': '녹근로33',
#    'telDisplay': '064-799-3340',
#    'context': ['돈가스'],
#    'reviewCount': 147,
#    'ktCallMd': '95eac56495552e98283d7bfecdded701',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20190704_291/1562230531407rCzdf_JPEG/z8pxkSHKyfGNAdc6VKl-j4r3.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.3143903',
#    'y': '33.4156850',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'pj/cY64YrVPPJEBr0OT+kg==',
#     'pan': '63.71',
#     'tilt': '10.00',
#     'lng': '126.3143046',
#     'lat': '33.4156426',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'http://instagram.com/_woo_lim_lee',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.314295, 'y': 33.415829}],
#     'walk': [{'rep': True, 'x': 126.314295, 'y': 33.415829}]},
#    'isPollingPlace': False,
#    'bizhourInfo': '금요일 11:00~15:45 | 화요일 11:00~15:45 | 월요일 11:00~15:45 | 평일 11:00~15:45 | 목요일 휴무 별도휴무시 인스타 공지 | 수요일 휴무 별도휴무시 인스타 공지 | 일요일 11:00~15:45 | 토요일 11:00~15:45 | 주말 11:00~15:45',
#    'menuInfo': '라클렛돈까스 16,000 | 녹근로돈까스 11,000 | 고기국수 8,000 | 비빔국수 8,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3516.26',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': ['치즈 이불을 덮은 흑돼지 돈까스가 유명한 집',
#     '제주흑돼지돈가스도 맛있지만 비빔국수',
#     '돈까스와 고기국수 제주도민도 추천한 맛집',
#     '라클렛돈까스로 유명한 한림 맛집',
#     '애월읍에 숨겨진 돈까스맛집'],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '5',
#    'rank': '6',
#    'id': '19873713',
#    'name': '만민식당',
#    'tel': '064-796-4473',
#    'isCallLink': False,
#    'virtualTel': '',
#    'ppc': '1',
#    'category': ['한식', '해물,생선요리'],
#    'categoryPath': [['220036', '220037', '220076', '220777'],
#     ['1004760', '1004452']],
#    'address': '제주특별자치도 제주시 한림읍 동명리 138-3',
#    'roadAddress': '제주특별자치도 제주시 한림읍 중산간서로 4618-1',
#    'abbrAddress': '동명리 138-3',
#    'shortAddress': ['제주 제주시 한림읍', '중산간서로 4618-1'],
#    'display': '만민<b>식당</b>',
#    'telDisplay': '064-796-4473',
#    'context': ['해물전골', '갈치조림', '해물찜', '싱싱한', '전복뚝배기'],
#    'reviewCount': 450,
#    'ktCallMd': 'f9f71eaf09bb88d88670cf7a394d1249',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20170523_138/1495520997647gIqcY_PNG/_6.png',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2842520',
#    'y': '33.3839048',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'NaFbKfs3KXArQASWYZJfGw==',
#     'pan': '38.45',
#     'tilt': '0.06',
#     'lng': '126.2836963',
#     'lat': '33.3835184',
#     'fov': '80'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'http://instagram.com/jeju_manmin',
#    'description': '',
#    'entranceCoords': None,
#    'isPollingPlace': False,
#    'bizhourInfo': '토요일 09:00~21:00 (마지막주문 20:00) | 금요일 09:00~21:00 (마지막주문 20:00) | 목요일 09:00~21:00 (마지막주문 20:00) | 수요일 09:00~21:00 (마지막주문 20:00) | 화요일 09:00~21:00 (마지막주문 20:00) | 월요일 휴무 매주 | 일요일 09:00~20:00 (마지막 주문 19:00)',
#    'menuInfo': '갈치조림 대 88,000 | 해물탕 대 75,000 | 통갈치조림 190,000 | 소주 5,000 | 맥주 5,000 | 갈치조림 중 78,000 | 갈치조림 소 58,000 | 해물탕 중 65,000 | 해물탕 소 50,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3503.24',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': ['전통의 가성비 좋은 푸짐한 제주 한림 해물탕',
#     '한림 맛집 원산지 제주산 해산물이 가득한 리얼 제주 해물탕',
#     '현지인도 인정한 해물탕 존맛탱집',
#     '제주시 해물탕 값싸고 맛있는 곳',
#     '성게알이 들어간 시원한 해물탕'],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '6',
#    'rank': '7',
#    'id': '1836873478',
#    'name': '아니따 파스타',
#    'tel': '010-2238-4080',
#    'isCallLink': False,
#    'virtualTel': '0507-1491-4082',
#    'ppc': '1',
#    'category': ['이탈리아음식', '스파게티,파스타전문'],
#    'categoryPath': [['220036', '220044', '220127', '220914', '230079'],
#     ['1004760', '1005205']],
#    'address': '제주특별자치도 제주시 한림읍 금악리 2124-4 제주 한림 파스타 아니따',
#    'roadAddress': '제주특별자치도 제주시 한림읍 금악로1길 1 제주 한림 파스타 아니따',
#    'abbrAddress': '금악리 2124-4 제주 한림 파스타 아니따',
#    'shortAddress': ['제주 제주시 한림읍', '금악로1길 1', '제주 한림 파스타 아니따'],
#    'display': '아니따 파스타',
#    'telDisplay': '010-2238-4080',
#    'context': [],
#    'reviewCount': 248,
#    'ktCallMd': 'd4c65bf9e1ad6a9ccdf5b8f7e592fffd',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20220228_143/1646046280349YlfTc_JPEG/C03C574B-5D99-4688-BEF9-95989642EA10.jpeg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2963134',
#    'y': '33.3588467',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': '2dPEkLfiZnrx+YX0Pc+rNQ==',
#     'pan': '-26.24',
#     'tilt': '10.00',
#     'lng': '126.2963504',
#     'lat': '33.3587716',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'http://instagram.com/anitta._.jeju',
#    'description': '',
#    'entranceCoords': None,
#    'isPollingPlace': False,
#    'bizhourInfo': '매일 11:00~17:00',
#    'menuInfo': '감태페스토 파스타 17,900 | 흑돼지 라구 파스타 13,900 | 갑오징어 명란 파스타 15,900 | 바질페스토 파스타 16,900 | 트러플 크림 뇨끼 17,900 | 바질 토마토 샐러드 8,900 | 바질 토마토 샐러드(부라타치즈 추가) 5,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': True,
#    'broadcastInfo': {'name': '백종원의골목식당', 'menu': '흑돼지라구파스타/감태페스토파스타'},
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3737.11',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '7',
#    'rank': '8',
#    'id': '38554778',
#    'name': '오데뜨',
#    'tel': '064-799-2748',
#    'isCallLink': False,
#    'virtualTel': '',
#    'ppc': '1',
#    'category': ['이탈리아음식', '스파게티,파스타전문'],
#    'categoryPath': [['220036', '220044', '220127', '220914', '230079'],
#     ['1004760', '1004452']],
#    'address': '제주특별자치도 제주시 한림읍 상대리 2887 오데뜨',
#    'roadAddress': '제주특별자치도 제주시 한림읍 중산간서로 4995-6 오데뜨',
#    'abbrAddress': '상대리 2887 오데뜨',
#    'shortAddress': ['제주 제주시 한림읍', '중산간서로 4995-6', '오데뜨'],
#    'display': '오데뜨',
#    'telDisplay': '064-799-2748',
#    'context': ['크림파스타', '전복', '빈티지한', '사진찍기', '크림카레우동'],
#    'reviewCount': 321,
#    'ktCallMd': '6eccd9ebf17b30a29f6bcc766c666522',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20181115_118/1542272426975xRYo8_JPEG/pbtFE2swFPWYaZLIA4NPH37B.jpeg.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2955745',
#    'y': '33.4108749',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'dsO+57rX7xl4Jeqz9sM2Tw==',
#     'pan': '-76.96',
#     'tilt': '10.00',
#     'lng': '126.2960163',
#     'lat': '33.4107723',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'https://www.instagram.com/odett_she',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.295923, 'y': 33.410784}],
#     'walk': [{'rep': True, 'x': 126.295923, 'y': 33.410784}]},
#    'isPollingPlace': False,
#    'bizhourInfo': '매일 12:00~20:00 브레이크타임 15:00-16:00 | 월요일 휴무 매주 월요일 휴무 입니다.',
#    'menuInfo': '전복삼합 33,000 | 흑돼지안심카레크림우동 16,000 | 전복리조또 17,000 | 흑돼지안심스테이크 18,000 | 반려견스테이크 9,000 | 날치알새우크림우동 15,000 | 흑돼지안심덮밥 15,000 | 핑크크림우동 14,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3803.93',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '8',
#    'rank': '9',
#    'id': '1249238360',
#    'name': '치꼬 타코전문점',
#    'tel': '010-7963-2239',
#    'isCallLink': False,
#    'virtualTel': '0507-1448-2252',
#    'ppc': '1',
#    'category': ['음식점', '멕시코,남미음식'],
#    'categoryPath': [['220036', '220044', '220132', '220930'],
#     ['1004760', '1004380', '1004431']],
#    'address': '제주특별자치도 제주시 한림읍 금악리 2096-5',
#    'roadAddress': '제주특별자치도 제주시 한림읍 금악로 18',
#    'abbrAddress': '금악리 2096-5',
#    'shortAddress': ['제주 제주시 한림읍', '금악로 18'],
#    'display': '치꼬 타코전문점',
#    'telDisplay': '010-7963-2239',
#    'context': [],
#    'reviewCount': 165,
#    'ktCallMd': 'e018fae05b403dae119001fdb38e7fdd',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20220719_180/1658217067024CKdjY_JPEG/KakaoTalk_20220719_164834323_08.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2966353',
#    'y': '33.3586515',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 's9evn66iRiW51JcZe7qwhA==',
#     'pan': '111.69',
#     'tilt': '10.00',
#     'lng': '126.2965168',
#     'lat': '33.3586985',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'http://chiconaverplace.영상메뉴판보기.com',
#    'description': '',
#    'entranceCoords': None,
#    'isPollingPlace': False,
#    'bizhourInfo': None,
#    'menuInfo': '까르니따스 타코 1인분 2PSC 6,900 | 까르니따스 밀키트 3인분기준(7조각) 18,000 | 초리조 타코 1인분 2PCS 6,900 | 새우 타코 1인분 2PCS 7,500 | 도세끼스 라거 6,000 | 호세 쿠엘보 (더블샷) 6,000 | 하리토스 멕시코 탄산음료 5,500',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': True,
#    'broadcastInfo': {'name': '백종원의골목식당', 'menu': '까르니따스타코'},
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3734.97',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '9',
#    'rank': '10',
#    'id': '1825766134',
#    'name': '꿀봉',
#    'tel': '064-796-0911',
#    'isCallLink': False,
#    'virtualTel': '0507-1441-2210',
#    'ppc': '1',
#    'category': ['분식', '종합분식'],
#    'categoryPath': [['220036', '220048', '220185'],
#     ['1004760', '1004380', '1004431']],
#    'address': '제주특별자치도 제주시 한림읍 금악리 2124-3 꿀봉',
#    'roadAddress': '제주특별자치도 제주시 한림읍 금악로1길 3 꿀봉',
#    'abbrAddress': '금악리 2124-3 꿀봉',
#    'shortAddress': ['제주 제주시 한림읍', '금악로1길 3', '꿀봉'],
#    'display': '꿀봉',
#    'telDisplay': '064-796-0911',
#    'context': [],
#    'reviewCount': 242,
#    'ktCallMd': '186ad8e5340948b660e6ea7ac31a0ab9',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20220819_293/1660897337883mSfrG_JPEG/FD2244B5-9564-40F3-877A-5C3425B678AF.jpeg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2963475',
#    'y': '33.3590274',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'g0RUQgDhPs9yj+qfpGqdlg==',
#     'pan': '-86.12',
#     'tilt': '18.27',
#     'lng': '126.2964521',
#     'lat': '33.3590365',
#     'fov': '100'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'https://www.instagram.com/ggulbong_jeju',
#    'description': '',
#    'entranceCoords': None,
#    'isPollingPlace': False,
#    'bizhourInfo': '매일 10:00~17:00 재료소진시 조기마감됩니다',
#    'menuInfo': '꿀봉강정 6,500 | 허니치즈 6,500 | 커민칠리 6,500 | 세가지맛세트 18,000 | 콜라 / 스프라이트 2,500',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': True,
#    'broadcastInfo': {'name': '백종원의골목식당', 'menu': '한라봉강정/허니치즈강정/커민칠리강정'},
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3719.61',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '10',
#    'rank': '11',
#    'id': '1031606380',
#    'name': '금악 똣똣라면',
#    'tel': '010-7120-8253',
#    'isCallLink': False,
#    'virtualTel': '0507-1490-8265',
#    'ppc': '1',
#    'category': ['분식', '라면'],
#    'categoryPath': [['220036', '220048', '220188']],
#    'address': '제주특별자치도 제주시 한림읍 금악리 2096-5',
#    'roadAddress': '제주특별자치도 제주시 한림읍 금악로 18',
#    'abbrAddress': '금악리 2096-5',
#    'shortAddress': ['제주 제주시 한림읍', '금악로 18'],
#    'display': '금악 똣똣라면',
#    'telDisplay': '010-7120-8253',
#    'context': [],
#    'reviewCount': 287,
#    'ktCallMd': 'c8be09c4b03cf813989dc1ecabbeef0e',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20210913_51/1631500306707bpVAA_JPEG/wMFiXaH21kkwYYmLnpzNzQMC.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2966353',
#    'y': '33.3586515',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 's9evn66iRiW51JcZe7qwhA==',
#     'pan': '111.69',
#     'tilt': '10.00',
#     'lng': '126.2965168',
#     'lat': '33.3586985',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'http://dotdotnaverplace.영상메뉴판보기.com',
#    'description': '',
#    'entranceCoords': None,
#    'isPollingPlace': False,
#    'bizhourInfo': None,
#    'menuInfo': '키즈메뉴개발중 변동가격(업주문의) | 똣똣라면 6,500 | 몸밥 1,500 | 탄산음료 2,500',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': True,
#    'broadcastInfo': {'name': '백종원의골목식당', 'menu': '라면'},
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3734.97',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '11',
#    'rank': '12',
#    'id': '1782800882',
#    'name': '영국찻집',
#    'tel': '',
#    'isCallLink': False,
#    'virtualTel': '',
#    'ppc': '0',
#    'category': ['음식점', '카페,디저트'],
#    'categoryPath': [['220036', '220052', '220563'], ['1004760', '1004452']],
#    'address': '제주특별자치도 제주시 애월읍 봉성리 3138',
#    'roadAddress': '제주특별자치도 제주시 애월읍 녹근로 19-15',
#    'abbrAddress': '봉성리 3138',
#    'shortAddress': ['제주 제주시 애월읍', '녹근로 19-15'],
#    'display': '영국찻집',
#    'telDisplay': '',
#    'context': [],
#    'reviewCount': 395,
#    'ktCallMd': '2d178cb91c7bb9920aeb87267c5069f9',
#    'coupon': '0',
#    'thumUrl': None,
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.3141137',
#    'y': '33.4172391',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'bvJVrZ28Hsdu7CimreXHlg==',
#     'pan': '-81.51',
#     'tilt': '10.00',
#     'lng': '126.3144417',
#     'lat': '33.4171899',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'https://instagram.com/gb_tea_room',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.314058, 'y': 33.416873}],
#     'walk': [{'rep': True, 'x': 126.314058, 'y': 33.416873}]},
#    'isPollingPlace': False,
#    'bizhourInfo': '월요일 13:00~18:00 매주 수요일,목요일 휴무 | 화요일 13:00~18:00 인스타그램 참고 바랍니다. | 금요일 13:00~18:00 매주 수요일,목요일 휴무 | 토요일 13:00~18:00 인스타그램 참고 바랍니다. | 일요일 13:00~18:00 매주 수요일,목요일 휴무',
#    'menuInfo': '잉글리시 브렉퍼스트 5,000 | 다즐링 5,500 | 얼 그레이 5,500 | 레이디 그레이 5,500 | 우바 6,000 | 페어리로즈 (디카페인) 6,000 | 밀크티 (달콤) 6,500 | 밀크티 (단짠) 6,500 | 애플 얼그레이 7,000 | 스콘 6,500 | 오이샌드위치 5,500 | 폼 밀크티 7,000 | 잠봉뵈르 11,000 | 초코바나나 푸딩 7,500 | 레몬무화과 푸딩 7,500',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3690.87',
#    'marker': 'nres://marker/00079-00037',
#    'markerSelected': 'nres://marker/00079-00200',
#    'microReview': ['맛있는 차와 디저트가 있는 애월 신상카페',
#     '인스타 감성 넘치는 제주 애월 카페',
#     '동화같은 애월 카페',
#     '인스타에서 핫한 제주 애월 카페',
#     '애월 동화 속에 있는 것 같은 햇살맛집'],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '12',
#    'rank': '13',
#    'id': '17028601',
#    'name': '봉성식당',
#    'tel': '064-799-0011',
#    'isCallLink': False,
#    'virtualTel': '0507-1434-0068',
#    'ppc': '1',
#    'category': ['한식', '돼지고기구이'],
#    'categoryPath': [['220036', '220037', '220075', '220765', '221458'],
#     ['1004760', '1004452']],
#    'address': '제주특별자치도 제주시 애월읍 봉성리 4124-1',
#    'roadAddress': '제주특별자치도 제주시 애월읍 봉성로 66 봉성식당',
#    'abbrAddress': '봉성리 4124-1',
#    'shortAddress': ['제주 제주시 애월읍', '봉성로 66', '봉성식당'],
#    'display': '봉성<b>식당</b>',
#    'telDisplay': '064-799-0011',
#    'context': ['근고기', '흑돼지', '김치찌개', '유기농', '냉면'],
#    'reviewCount': 327,
#    'ktCallMd': 'd71d13b77b59d6a2f2fc3d58abdad5ca',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20160616_152/1466058326921BGA95_JPEG/176560515030745_0.jpeg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.3126080',
#    'y': '33.4186876',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': '23FG7nFJU8WxNoizMCwHRg==',
#     'pan': '72.05',
#     'tilt': '10.00',
#     'lng': '126.3125049',
#     'lat': '33.4186542',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'http://instagram.com/bongseong0011',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.312569, 'y': 33.418851}],
#     'walk': [{'rep': True, 'x': 126.312569, 'y': 33.418851}]},
#    'isPollingPlace': False,
#    'bizhourInfo': '매일 11:00~22:00 Break Time 15시~16시30분 / 매월 둘째주,넷째주 화요일 휴무/ Last order 21시30분👋',
#    'menuInfo': '제주산 흑돼지 목살/오겹살(600g) 65,000 | 제주산 백돼지 목살/오겹살(600g) 50,000 | 김치찌개 소 8,000 | 열무국수 7,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3877.91',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '13',
#    'rank': '14',
#    'id': '1167467485',
#    'name': '금악무짠지냉면',
#    'tel': '064-796-6367',
#    'isCallLink': False,
#    'virtualTel': '',
#    'ppc': '1',
#    'category': ['한식', '냉면'],
#    'categoryPath': [['220036', '220037', '220063', '220645']],
#    'address': '제주특별자치도 제주시 한림읍 금악리 2134-1',
#    'roadAddress': '제주특별자치도 제주시 한림읍 금악로1길 15',
#    'abbrAddress': '금악리 2134-1',
#    'shortAddress': ['제주 제주시 한림읍', '금악로1길 15'],
#    'display': '금악무짠지냉면',
#    'telDisplay': '064-796-6367',
#    'context': [],
#    'reviewCount': 159,
#    'ktCallMd': '8afd01c20756e03d277b9a599a4f0585',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20210614_22/1623651244779BxFUX_JPEG/sCo3ktvhGaImHB6ITh3sf5Hd.jpeg.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2942825',
#    'y': '33.3600613',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'jedHTEuD0LNnm7zeLRvkeQ==',
#     'pan': '-136.62',
#     'tilt': '-0.71',
#     'lng': '126.2945324',
#     'lat': '33.3601789',
#     'fov': '100'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'http://mujjanjinaverplace.영상메뉴판보기.com',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True,
#       'x': 126.2945426,
#       'y': 33.3602078}],
#     'walk': [{'rep': True, 'x': 126.2945426, 'y': 33.3602078}]},
#    'isPollingPlace': False,
#    'bizhourInfo': '수요일 휴무 | 매일 11:00~16:30 라스트오더 16:30',
#    'menuInfo': '물냉 8,000 | 비냉 8,000 | 고기완자 6,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3760.36',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '14',
#    'rank': '15',
#    'id': '1504985857',
#    'name': '제주코 흑돼지 제주금능협재점',
#    'tel': '064-796-5689',
#    'isCallLink': False,
#    'virtualTel': '0507-1387-5690',
#    'ppc': '1',
#    'category': ['한식', '육류,고기요리'],
#    'categoryPath': [['220036', '220037', '220075', '220733'],
#     ['1004760', '1004452']],
#    'address': '제주특별자치도 제주시 한림읍 명월리 405-11',
#    'roadAddress': '제주특별자치도 제주시 한림읍 중산간서로 4494',
#    'abbrAddress': '명월리 405-11',
#    'shortAddress': ['제주 제주시 한림읍', '중산간서로 4494'],
#    'display': '제주코 흑돼지 제주금능협재점',
#    'telDisplay': '064-796-5689',
#    'context': [],
#    'reviewCount': 34,
#    'ktCallMd': '76055d04d8b7ef87ae90cfe6d7938fab',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20220412_190/164972587515346Ikg_JPEG/9827A04B-617C-4718-B745-B62C406729D3.jpeg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2845568',
#    'y': '33.3728221',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': '12bbHDu0Z8CJm7uYa+1ZIg==',
#     'pan': '112.33',
#     'tilt': '10.00',
#     'lng': '126.2842792',
#     'lat': '33.3729358',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'https://www.instagram.com/jejuko_pig',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.284328, 'y': 33.372691}],
#     'walk': [{'rep': True, 'x': 126.284328, 'y': 33.372691}]},
#    'isPollingPlace': False,
#    'bizhourInfo': '평일 11:30~21:00 | 일요일 휴무',
#    'menuInfo': '제주코 시그니처 흑돼지 모듬 - 2인 40,000 | 제주코 자가제면 물냉면 8,000 | [점심특선] 제주코돼지세트 (1인) 14,000 | 제주코 가마솥곰탕 10,000 | 뜯고 맛보고 즐기는 돼지 생갈비 18,000 | 제주코 시그니처 흑돼지 모듬 - 4인 80,000 | 제주코 자가제면 비빔냉면 8,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '3717.93',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '15',
#    'rank': '16',
#    'id': '1460763762',
#    'name': '봉성프리마',
#    'tel': '010-2011-4430',
#    'isCallLink': False,
#    'virtualTel': '0507-1325-4430',
#    'ppc': '1',
#    'category': ['음식점', '카페,디저트'],
#    'categoryPath': [['220036', '220052', '220563'], ['1004760', '1004452']],
#    'address': '제주특별자치도 제주시 애월읍 봉성리 4086',
#    'roadAddress': '제주특별자치도 제주시 애월읍 봉성로2길 16-1',
#    'abbrAddress': '봉성리 4086',
#    'shortAddress': ['제주 제주시 애월읍', '봉성로2길 16-1'],
#    'display': '봉성프리마',
#    'telDisplay': '010-2011-4430',
#    'context': [],
#    'reviewCount': 170,
#    'ktCallMd': 'ec9ee85effcb44a191d80eb359cf4e5e',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20220602_287/16541434364422LJvA_JPEG/E0B8E9DD-E762-4847-A44A-BF87CB78A6A6.jpeg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.3115455',
#    'y': '33.4163378',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'j/nL7xkgppAc9vs8Wgxm8w==',
#     'pan': '-23.62',
#     'tilt': '10.00',
#     'lng': '126.3115949',
#     'lat': '33.4162251',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'http://instagram.com/bongseongprima.jeju',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.311535, 'y': 33.416232}],
#     'walk': [{'rep': True, 'x': 126.311535, 'y': 33.416232}]},
#    'isPollingPlace': False,
#    'bizhourInfo': '목요일 11:00~18:00 | 금요일 11:00~18:00 | 일요일 11:00~18:00 | 토요일 11:00~18:00 | 월요일 11:00~18:00 | 수요일 휴무 | 화요일 휴무',
#    'menuInfo': '쫀득바-버터가득진한맛 변동가격(업주문의) | 츄러스휘낭시에 3,000 | 봉성리카노 5,000 | 패션후르츠에이드 6,500 | 마카롱 2,800 | 밀크티(아쌈다즐링) 6,500 | 봉성슈페너 6,500 | 청귤에이드❤️ 6,500',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
# ...
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '6870.62',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '95',
#    'rank': '116',
#    'id': '1885671682',
#    'name': '카페이시도르',
#    'tel': '064-796-0677',
#    'isCallLink': False,
#    'virtualTel': '',
#    'ppc': '1',
#    'category': ['카페,디저트', '카페'],
#    'categoryPath': [['220036', '220052', '220576', '221212'],
#     ['1004760', '1004452']],
#    'address': '제주특별자치도 제주시 한림읍 금악리 117 성이시돌센터 카페이시도르',
#    'roadAddress': '제주특별자치도 제주시 한림읍 금악북로 353 성이시돌센터 카페이시도르',
#    'abbrAddress': '금악리 117 성이시돌센터 카페이시도르',
#    'shortAddress': ['제주 제주시 한림읍', '금악북로 353', '성이시돌센터 카페이시도르'],
#    'display': '카페이시도르',
#    'telDisplay': '064-796-0677',
#    'context': [],
#    'reviewCount': 57,
#    'ktCallMd': 'c0a6706bf07f8255748cfa7592116260',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20190808_210/1565240240298WAabm_JPEG/oC6lX8qMosN1zOyAvsmG-UNQ.jpeg.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.3225896',
#    'y': '33.3466358',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'GtDwB/4hMhORUtZUg9hrvQ==',
#     'pan': '75.17',
#     'tilt': '10.00',
#     'lng': '126.3223279',
#     'lat': '33.3465663',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': '',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.322335, 'y': 33.347128}],
#     'walk': [{'rep': True, 'x': 126.322335, 'y': 33.347128}]},
#    'isPollingPlace': False,
#    'bizhourInfo': '매일 09:00~17:00 정기휴무없음',
#    'menuInfo': '커피 변동가격(업주문의) | 차 변동가격(업주문의)',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '4239.36',
#    'marker': 'nres://marker/00079-00037',
#    'markerSelected': 'nres://marker/00079-00200',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '96',
#    'rank': '117',
#    'id': '16858457',
#    'name': '시골마을',
#    'tel': '064-796-6707',
#    'isCallLink': False,
#    'virtualTel': '',
#    'ppc': '1',
#    'category': ['음식점', '한식'],
#    'categoryPath': [['220036', '220037', '220053'],
#     ['1004760', '1004380', '1002043']],
#    'address': '제주특별자치도 제주시 한림읍 귀덕리 2290',
#    'roadAddress': '제주특별자치도 제주시 한림읍 한수풀로 263',
#    'abbrAddress': '귀덕리 2290',
#    'shortAddress': ['제주 제주시 한림읍', '한수풀로 263'],
#    'display': '시골마을',
#    'telDisplay': '064-796-6707',
#    'context': [],
#    'reviewCount': 3,
#    'ktCallMd': 'a2761084df4f74c2e8dafb0a2adafb0d',
#    'coupon': '0',
#    'thumUrl': None,
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2889862',
#    'y': '33.4193723',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'tI6zc46TKDVbM+XmNC/kRA==',
#     'pan': '-42.44',
#     'tilt': '10.00',
#     'lng': '126.2895036',
#     'lat': '33.4188061',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': '',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.288933, 'y': 33.419086}],
#     'walk': [{'rep': True, 'x': 126.288933, 'y': 33.419086}]},
#    'isPollingPlace': False,
#    'bizhourInfo': None,
#    'menuInfo': None,
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '0',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '4923.55',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '97',
#    'rank': '118',
#    'id': '13272519',
#    'name': '배터지는생동까스 한림점',
#    'tel': '064-796-9925',
#    'isCallLink': False,
#    'virtualTel': '',
#    'ppc': '1',
#    'category': ['일식', '돈가스'],
#    'categoryPath': [['220036', '220038', '220082', '230897'],
#     ['1004760', '1004380', '1004431']],
#    'address': '제주특별자치도 제주시 한림읍 한림리 1094 1층',
#    'roadAddress': '제주특별자치도 제주시 한림읍 내동길 12 1층',
#    'abbrAddress': '한림리 1094 1층',
#    'shortAddress': ['제주 제주시 한림읍', '내동길 12', '1층'],
#    'display': '배터지는생동까스 한림점',
#    'telDisplay': '064-796-9925',
#    'context': [],
#    'reviewCount': 14,
#    'ktCallMd': '988d13f1eef49db325e07a6423a25673',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20220203_275/1643881960045agOjt_JPEG/IMG_20211217_111350_000.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2652847',
#    'y': '33.4138117',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': '3CoMOI3tD6cI90yKTaLzbA==',
#     'pan': '-164.83',
#     'tilt': '10.00',
#     'lng': '126.2653407',
#     'lat': '33.4140171',
#     'fov': '120'},
#    'skyPanorama': {'id': '7hYHikicgfSD+IpNIRwGRg==',
#     'pan': '94.17',
#     'tilt': '-30.00',
#     'lng': '126.2597279',
#     'lat': '33.4142122',
#     'fov': '124'},
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'https://blog.naver.com/yuripark62',
#    'description': '',
#    'entranceCoords': None,
#    'isPollingPlace': False,
#    'bizhourInfo': '평일 10:00~21:00',
#    'menuInfo': '고구마치즈돈까스 10,000 | 찹쌀전복죽 13,000 | 김치치즈롤 10,000 | 피자돈까스 10,000 | 고구마돈까스 10,000 | 나이스짱모듬돈가스 9,500 | 배터지는생돈가스 9,500 | 제육덮밥 9,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '6179.49',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '98',
#    'rank': '119',
#    'id': '1099527289',
#    'name': '노랑통닭 제주 한림점',
#    'tel': '064-796-8292',
#    'isCallLink': False,
#    'virtualTel': '0507-1483-8296',
#    'ppc': '1',
#    'category': ['음식점', '치킨,닭강정'],
#    'categoryPath': [['220036', '220049', '220295']],
#    'address': '제주특별자치도 제주시 한림읍 한림리 942-6 1층',
#    'roadAddress': '제주특별자치도 제주시 한림읍 한림중앙로 32 1층',
#    'abbrAddress': '한림리 942-6 1층',
#    'shortAddress': ['제주 제주시 한림읍', '한림중앙로 32', '1층'],
#    'display': '노랑통닭 제주 한림점',
#    'telDisplay': '064-796-8292',
#    'context': [],
#    'reviewCount': 4,
#    'ktCallMd': '054a86930e69adae701fa73b67b6878e',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20200801_296/15962708052022lTNU_JPEG/y6NeJ8xfRvL5s1FvY9pHPMhB.jpeg.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.2650130',
#    'y': '33.4117360',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': '4kiWBRUvUEJE3G1phEDC1w==',
#     'pan': '-91.35',
#     'tilt': '6.25',
#     'lng': '126.2652195',
#     'lat': '33.4117425',
#     'fov': '90'},
#    'skyPanorama': {'id': '7hYHikicgfSD+IpNIRwGRg==',
#     'pan': '115.16',
#     'tilt': '-30.00',
#     'lng': '126.2597279',
#     'lat': '33.4142122',
#     'fov': '124'},
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': '',
#    'description': '',
#    'entranceCoords': {'car': [{'rep': True, 'x': 126.26509, 'y': 33.411724}],
#     'walk': [{'rep': True, 'x': 126.26509, 'y': 33.411724}]},
#    'isPollingPlace': False,
#    'bizhourInfo': '매일 12:00~00:00',
#    'menuInfo': '맵싸한고추치킨 21,000 | 맵싸한고추치킨 레귤러 19,000 | 뿌리노랑치킨 22,000 | 뿌리노랑치킨 레귤러 20,000 | 바삭누룽지치킨 21,000 | 바삭누룽지치킨 레귤러 19,000 | 알싸한 마늘치킨 사이즈업 22,000 | 알싸한 마늘치킨 레귤러 20,000 | 엄청 큰 후라이드 치킨 19,000 | 후라이드치킨 레굴러사이즈 17,000 | 순살 3종 세트 22,000 | 엄청 큰 양념치킨 21,000 | 양념치킨 레귤러 19,000 | 엄청 큰 깐풍치킨 21,000 | 깐풍치킨 레귤러 19,000 | 엄청 큰 반반치킨 (후라이드+양념) 20,000 | 엄청 큰 반반치킨 (후라이드+깐풍) 20,000 | 엄청 큰 반반치킨 (양념+깐풍) 22,000 | 고추장THE한치킨 22,000 | 간장THE한치킨 22,000 | 웰빙파닭 (후라이드+양념) 22,000 | 웰빙파닭 (후라이드+깐풍) 22,000 | 웰빙파닭 (양념+깐풍) 23,000 | 똥집감자튀김 14,000 | 낀풍똥집튀김 15,000 | 노랑봉투감자 8,000 | 눈꽃치즈떡볶이 7,000 | 3종치즈볼 5,000 | 오리지널치즈볼(5개) 4,000 | 김말이 3,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '6083.66',
#    'marker': 'nres://marker/00079-00043',
#    'markerSelected': 'nres://marker/00079-00206',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}},
#   {'index': '99',
#    'rank': '120',
#    'id': '1550978230',
#    'name': '새별하노이',
#    'tel': '064-792-6554',
#    'isCallLink': False,
#    'virtualTel': '0507-1389-6554',
#    'ppc': '1',
#    'category': ['음식점', '베트남음식'],
#    'categoryPath': [['220036', '220041', '220103'],
#     ['1004760', '1004380', '1002043']],
#    'address': '제주특별자치도 제주시 애월읍 봉성리 4554',
#    'roadAddress': '제주특별자치도 제주시 애월읍 평화로 1529',
#    'abbrAddress': '봉성리 4554',
#    'shortAddress': ['제주 제주시 애월읍', '평화로 1529'],
#    'display': '새별하노이',
#    'telDisplay': '064-792-6554',
#    'context': [],
#    'reviewCount': 69,
#    'ktCallMd': '634b481c8109c58337c3fd90ac07f08d',
#    'coupon': '0',
#    'thumUrl': 'https://ldb-phinf.pstatic.net/20211202_69/1638439411295THMNH_JPEG/KakaoTalk_20211202_185419297.jpg',
#    'type': 's',
#    'isSite': '1',
#    'posExact': '1',
#    'x': '126.3634385',
#    'y': '33.3645089',
#    'itemLevel': '12',
#    'isAdultBusiness': False,
#    'streetPanorama': {'id': 'GLdKJDqLfe+STAiif020LQ==',
#     'pan': '20.81',
#     'tilt': '10.00',
#     'lng': '126.3633572',
#     'lat': '33.3642949',
#     'fov': '120'},
#    'skyPanorama': None,
#    'insidePanorama': None,
#    'interiorPanorama': None,
#    'indoorPanorama': None,
#    'theme': None,
#    'poiInfo': {'relation': None,
#     'hasRelation': False,
#     'road': {'poiShapeType': '1',
#      'shapeKey': None,
#      'boundary': None,
#      'detail': None},
#     'hasRoad': False,
#     'land': None,
#     'hasLand': False,
#     'polygon': None,
#     'hasPolygon': False},
#    'homePage': 'https://www.instagram.com/saebyeol_hanoi',
#    'description': '',
#    'entranceCoords': None,
#    'isPollingPlace': False,
#    'bizhourInfo': '매일 11:00~19:30 연중무휴(마지막 주문 19:00)',
#    'menuInfo': '소고기양지쌀국수 9,500 | 똠양꿍쌀국수 11,000 | 분짜 13,000 | 반쎄오 17,000 | 소고기볶음밥 10,000 | 파인애플볶음밥 13,000 | 모닝글로리볶음 12,000 | 월남쌈 10,000 | 짜조 10,000 | 새우후라이링 10,000',
#    'petrolInfo': None,
#    'couponUrl': None,
#    'couponUrlMobile': None,
#    'hasCardBenefit': False,
#    'menuExist': '1',
#    'hasNaverBooking': False,
#    'naverBookingUrl': '',
#    'naverEasyOrderUrl': None,
#    'hasNaverSmartOrder': False,
#    'reservationLabel': {'standard': False,
#     'preOrder': False,
#     'table': False,
#     'takeout': False},
#    'reservation': {'benefit': ''},
#    'hasBroadcastInfo': False,
#    'broadcastInfo': None,
#    'shopWindowInfo': None,
#    'hasNPay': False,
#    'carWash': '',
#    'parkingPrice': None,
#    'card': None,
#    'distance': '4465.21',
#    'marker': 'nres://marker/00079-00162',
#    'markerSelected': 'nres://marker/00079-00326',
#    'microReview': [],
#    'michelinGuide': None,
#    'indoor': None,
#    'markerLabel': None,
#    'subway': None,
#    'evChargerInfo': {'summary': {'fastEvCharger': {'type': '급속',
#       'typeCode': '1',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []},
#      'standardEvCharger': {'type': '완속',
#       'typeCode': '2',
#       'status': '',
#       'statusCode': '-1',
#       'names': [],
#       'nameCodes': []}},
#     'evChargerList': []}}]}

# %%
len(places)
# Out:
# 3

# %%
# for k,v in places[1][50].items():
#     print(f"key: {k}, value: {v}")

# bus_id = [{k:v} for k,v in zip(places[1][0]['name'],places[1][0]['id'])]
# bus_id

place_id_dict = {}
for i in places.values():
    for j in i:
        place_id_dict[j['name']] = j['id']

place_id_dict
# Out:
# {'조식': '1633977299',
#  '어음밥집': '1439356450',
#  '어음분교1963': '1449299326',
#  '한라종합식품': '1051333889',
#  '녹근로33': '933405444',
#  '만민식당': '19873713',
#  '아니따 파스타': '1836873478',
#  '오데뜨': '38554778',
#  '치꼬 타코전문점': '1249238360',
#  '꿀봉': '1825766134',
#  '금악 똣똣라면': '1031606380',
#  '영국찻집': '1782800882',
#  '봉성식당': '17028601',
#  '금악무짠지냉면': '1167467485',
#  '제주코 흑돼지 제주금능협재점': '1504985857',
#  '봉성프리마': '1460763762',
#  '카페오드리': '407062195',
#  '7밀리그램': '1479613419',
#  '펜고호다': '1779892345',
#  'ARTE TEABAR': '1453073383',
#  '제주애단비 유안': '1461912091',
#  '윤정이네국밥': '1636100461',
#  '봉성리북까페': '1743462440',
#  '캘리포니아': '36531891',
#  '파스테이스': '1890368592',
#  '도치돌한우숯불': '13444840',
#  '새별식당': '1978317212',
#  '우무': '1537940586',
#  '옥만이네 해물갈비찜 밀키트 갈치조림': '1177704161',
#  '명월국민학교': '1383910337',
#  '푸른솔샘': '1078699146',
#  '승하네': '1997988273',
#  '금악정육식당': '37688110',
#  '제주통나무집': '17021963',
#  '뵤뵤': '1097948074',
#  '옥만이네 제주금능협재점': '960619161',
#  '금악핫도그': '1972322782',
#  '어박사 한림본점': '1952210476',
#  '어사촌도야지': '13398271',
#  '뽈살집한림점': '1330534461',
#  '달콤한휴식': '1844097380',
#  '양배추식당': '31485409',
#  '바당길': '819376798',
#  '도민상회 제주협재본점': '38265308',
#  '향토마을': '16864465',
#  '아르떼트레일러': '1337920295',
#  '다람쥐식탁': '37844914',
#  '정토': '1979624542',
#  '한림칼국수 제주본점': '34635305',
#  '제주도 해녀세자매': '1115697217',
#  '동명정류장': '1299502505',
#  '명랑스낵': '37413742',
#  '명산꿩농장가든': '36218330',
#  '금악국수': '1853720610',
#  '흑돼지팡': '1545843391',
#  '스토브온 제주': '1596213047',
#  '동명동락': '1514464724',
#  '문쏘 제주협재점': '38323100',
#  '제주명월역': '1955217282',
#  '경성수산': '1536054532',
#  '삼일식당': '16864917',
#  '씨리얼': '655562746',
#  '애월카페 푸르곤': '1196438364',
#  '제제하우스': '1033706480',
#  '초록달 과자점': '1810016105',
#  '제주막': '1030212097',
#  '애월7일': '1072771042',
#  '쉬리니케이크': '1056545447',
#  '한림보말칼국수': '34433147',
#  '이익새양과점': '299612944',
#  '카페 화가': '1810067601',
#  '인생밥집 제주협재점': '617945042',
#  '사브로소인제주': '1253195468',
#  '부원뚝배기': '16863333',
#  '바다제비': '1584030362',
#  '흑돼지촌 제주본점': '13196954',
#  '장촌한우마을': '16873331',
#  '뼈대감 본점': '16862893',
#  '돈내코순두부 한림점': '1545896995',
#  '바르왓 한림협재 본점': '1691872277',
#  '돈지정가든': '16864578',
#  '소이네김밥': '1415019990',
#  '미미슈': '1734008882',
#  '제주등대아구찜': '572933383',
#  '새빌': '1876553757',
#  '우리들식당': '37571824',
#  '36.5도여름 남쪽점': '1331785940',
#  '넥스트도어': '1824399841',
#  '못거리가든': '21824457',
#  '노고로시': '1789959499',
#  '비양놀': '1779931611',
#  'Anthracite Coffee 한림': '1006988399',
#  '카페유주': '1584217766',
#  '카페귤한가': '1000705551',
#  '허황후김치찜': '1872369973',
#  '옹포별장가든 제주협재본점': '19873662',
#  '돌연히,': '1675123806',
#  '육고깃집': '37046258',
#  '옹포83': '1760747516',
#  '송돈흑돼지 한림점': '1263956631',
#  '비타민국수': '16863184',
#  '흑심가': '1365461253',
#  '택이네해장국': '1227605021',
#  '제주홍돈 협재본점': '36804115',
#  '어림비로편의점': '1470998723',
#  '해물나무 제주한림점': '1888152265',
#  '사형제횟집': '13027660',
#  '제주백정 한림점': '1624930160',
#  '별난닭곰탕집 본점': '16860289',
#  '슈퍼마켓화이트버거스탠드': '1383225258',
#  '미향해장국': '36929004',
#  '타베니': '1817973410',
#  '우정해장국': '35627952',
#  '춘하추동식당': '16873393',
#  '모디카': '33510492',
#  '여러분제과점': '1905514099',
#  '알포인트커피': '1799083424',
#  '카페닐스': '38695952',
#  '면뽑는선생만두빚는아내': '36284467',
#  '콜체스카페': '1900992068',
#  '연화몽': '36615257',
#  '블랙씨걸': '1061474667',
#  '에코그린리조트': '35280080',
#  '일억조': '1030078190',
#  '한라축산정육식당': '37060922',
#  '한림칠돈가': '21031635',
#  'cafe064knot': '1538898096',
#  '애월후식': '1183075597',
#  '팥': '1077631280',
#  '아이스데이': '1457810887',
#  '동명리공간': '896977774',
#  '한입김밥': '37663275',
#  '제주새우닭': '1463340200',
#  '문어빵빵': '368184250',
#  '단소바': '1614785328',
#  '백부장집': '12052397',
#  '한림국수 집': '1566648812',
#  '황셰프양식당': '1820744408',
#  '멜톤': '1374761488',
#  '블루포밍': '1193905753',
#  '동백키친': '1386240526',
#  '카페코랫': '1935989504',
#  '영진보말칼국수 제주협재점': '1676569008',
#  '제주프리또': '182753219',
#  '돼지물고기 만원정식한상': '1848120285',
#  '다가미 한림점': '1970091673',
#  '전망대횟집': '11632890',
#  '오크라': '30825957',
#  '만강홍': '13120540',
#  '그시절그짬뽕': '1878870522',
#  '비주비주 한림점': '1575833048',
#  '앤트러사이트': '1240516940',
#  '탐나쑥빵': '1728198183',
#  '빨간집': '31877996',
#  '바다식당': '1624038539',
#  '제주시차': '1246755660',
#  '제주청정해담회센터 협재한림점': '1741992344',
#  '목간집': '1837721158',
#  '한림그때그집 제주협재점': '1141019901',
#  '한림도새기': '247648070',
#  '미정이네 꺼멍돗괴기': '1646167588',
#  '한림족발': '1866635933',
#  '차이나 인 제주': '1839539837',
#  '토리': '1873146415',
#  '황성옛터': '1232098689',
#  '꽁지삼춘네': '1577615496',
#  '피그농원': '1975409615',
#  '상명식당': '1665306171',
#  'by MOT': '1225509522',
#  '이화수전통육개장 제주한림점': '1894811782',
#  '참나무장작구이김서방 한림본점': '1731645635',
#  '롯타이': '1727227403',
#  '흑백돈 제주한림점': '16864986',
#  '스마일찹쌀꽈배기': '1437878599',
#  '메밀애': '37694310',
#  '샤브왕': '38321299',
#  '호호만다린하우스': '1406148984',
#  '낮에정식 밤에갈비': '1986651205',
#  '료리야': '1455026374',
#  '무호소반': '1901780590',
#  '아카렌가': '1754258376',
#  '카페리꼬': '1375419330',
#  '보영': '38290707',
#  '한림웅담수산': '1665925544',
#  '우리집': '12046079',
#  '제주 귀덕 골방 애월과협재사이': '1486669514',
#  '파노': '1410770412',
#  '포시즌스': '1893434747',
#  '한림바다생태체험마을': '16867375',
#  '호랑이다락': '1979084786',
#  '도원춘': '11559324',
#  '서촌제 제주한림점': '1564418796',
#  '요망지게 제주협재본점': '1113051649',
#  '명월반점': '1833963100',
#  '구르는제주카페': '1275050853',
#  '루스트플레이스 한림점': '1894533161',
#  '미크라트': '1047043307',
#  '일품 한림 횟집': '13435823',
#  '라신비라멘': '474937108',
#  '벌크커피 한림점': '1200236628',
#  '콩창고': '1434338666',
#  '라운지엑스 애월점': '1477105978',
#  '화닭발': '1580402936',
#  '수타명가': '872144190',
#  '황부자갈비': '19535819',
#  '톤대섬': '149975924',
#  '사이분식': '1788979291',
#  '친정가는날': '1222048586',
#  '아노록': '1737841317',
#  '이서순대국밥': '37470399',
#  '족발좌선생': '1425950143',
#  '귀덕향사': '1375159263',
#  '영림흑돼지가든': '11727639',
#  '제주미친흑돈': '37080528',
#  '황금손가락 한림점': '1016311144',
#  'BBQ제주한림점': '20098816',
#  '일빈관': '16860769',
#  '담카페': '1097090936',
#  '모메존감자탕 협재한림점': '1938989668',
#  '동명본가': '20671487',
#  '바스켓': '1007079226',
#  '7번가피자 제주한림점': '1739829671',
#  '네네치킨 제주한림점': '20174613',
#  '온월': '1721351471',
#  'ALEGRE': '1186161857',
#  '한림북카페 책한모금': '1495881597',
#  '우리뜰식당': '37064530',
#  '파스토': '1545154156',
#  '한림 억소리갈비': '1208631551',
#  '옥만이NE 제주협재점': '1038058575',
#  '좋은식탁': '1699655761',
#  '카페인어': '1518278430',
#  '우피후피': '1478272806',
#  '형제낙지': '1109966692',
#  '굴무기낭': '1915015443',
#  '서유기마라탕 한림점': '1239904809',
#  '록다미': '1403441170',
#  '풍년순대국밥': '33876929',
#  '오복성': '1136781040',
#  '뚜레쥬르 제주한림점': '1626762026',
#  '근쌀남': '1396333634',
#  '신전떡볶이 한림점': '725487206',
#  '똥파리와봉달이네 한림점': '1584560868',
#  '마당집': '36261106',
#  '한일식당': '16873167',
#  '한수풀더면': '1049526598',
#  '솔띠왓흥륭식당': '16865262',
#  '콩마루순두부짬뽕': '1303450475',
#  '교촌치킨 한림협재점': '38237032',
#  '난춘호랑이': '1014912249',
#  '한라초밥': '1515632473',
#  '한림항정육식당': '1520387503',
#  '미진식당': '16861985',
#  '우리마을': '113607412',
#  '람떼떼': '36342756',
#  '봉성붕어빵과오뎅': '1727437525',
#  '배스킨라빈스 제주한림': '37868046',
#  '제주연탄돼지불백': '1118439015',
#  '고향숯불막창한림점': '1532607286',
#  '담꾹 한림점': '1161459456',
#  '비마이게스트': '1297504158',
#  '보람순대국밥': '16860199',
#  '에그인선셋': '1996872981',
#  '스페이스 제로': '1188107137',
#  '다다식당': '33876932',
#  '명품김치찌개': '1404052601',
#  '태희보데가': '1265374669',
#  '돌고래식당': '1816101466',
#  '롱로드': '609263561',
#  '해물창고': '36323384',
#  '오태식해바라기치킨 한림점': '1135598683',
#  '느영나영혼듸모영 제주한림점': '1697010130',
#  '롯데리아 제주한림점': '37537433',
#  '굽네치킨 제주한림점': '32167334',
#  '펄랑': '1997239297',
#  '푸르메가 살고있는 곳': '698028056',
#  '요조조': '1435557792',
#  '차이나박하사': '1950368964',
#  '반미신짜오': '1584132654',
#  '동해호': '1808755816',
#  '삼정국수': '1435140968',
#  '일등정육백화점': '1067154563',
#  '그륻': '1159551290',
#  '30년할매닭발 한림점': '1843676555',
#  '브이아이피 VIP IN JEJU': '1875535092',
#  '로첼로': '1081566762',
#  '차롱': '37687506',
#  '삼춘네 바당뜰은': '37402662',
#  '한림정육점식당': '35642184',
#  'BHC치킨 제주한림점': '1437075589',
#  '파리바게뜨 제주한림점': '16860183',
#  '아방솟덕': '1236463393',
#  '몽실이네': '16863358',
#  '놀젠 만화카페': '1303583380',
#  '제주도모퉁이스낵연회장': '1682247440',
#  '카페이시도르': '1885671682',
#  '시골마을': '16858457',
#  '배터지는생동까스 한림점': '13272519',
#  '노랑통닭 제주 한림점': '1099527289',
#  '새별하노이': '1550978230'}

# %%
place_info = []
for idx,place in enumerate(place_id_dict.values()):
    place_info.append(requests.get(url=f'https://map.naver.com/v5/api/sites/summary/{place}?lang=ko',headers=headers).json())
    if idx == 5:
        break
    time.sleep(0.5)

# %%
pd.DataFrame(place_info).columns
# Out:
# Index(['id', 'isSite', 'name', 'type', 'rCode', 'x', 'y', 'posExact',
#        'address', 'fullAddress', 'addressAbbr', 'roadAddr', 'fullRoadAddress',
#        'phone', 'isCallLink', 'description', 'way', 'keywords',
#        'hasNaverTalktalkUrl', 'naverTalktalkUrl', 'adult', 'endPageUrl',
#        'mobileEndPageUrl', 'urlList', 'ktCallMd', 'ppc', 'images', 'imageURL',
#        'imageModDate', 'displayCategory', 'category', 'categories',
#        'categoryPaths', 'bizHour', 'bizhourInfo', 'options', 'menus',
#        'menuImages', 'previewImages', 'streetPanorama', 'skyPanorama',
#        'insidePanorama', 'interiorPanorama', 'indoorPanorama',
#        'entranceCoords', 'theme', 'hasNaverBooking', 'naverBookingUrl',
#        'naverbookingId', 'petrolInfo', 'michelinGuide', 'broadcastInfo',
#        'marker', 'markerSelected', 'datalab', 'reviewCount', 'dynamicData',
#        'markerLabel', 'isParkingSupported'],
#       dtype='object')

# %%
place_profile = pd.DataFrame(place_info)[['id','name','x','y','fullAddress','phone','description','images','imageURL','categories','bizhourInfo','menus','reviewCount']]
place_profile
# Out:
#            id      name           x          y  \
# 0  1633977299        조식  126.333206  33.410580
# 1  1439356450      어음밥집  126.339234  33.401998
# 2  1449299326  어음분교1963  126.338462  33.403274
# 3  1051333889    한라종합식품  126.318430  33.364895
# 4   933405444     녹근로33  126.314390  33.415685
# 5    19873713      만민식당  126.284252  33.383905
#
#                          fullAddress          phone  \
# 0         제주특별자치도 제주시 애월읍 어음리 3459-1
# 1         제주특별자치도 제주시 애월읍 어음리 2949-4   064-799-0788
# 2  제주특별자치도 제주시 애월읍 어음리 2922 어음분교1963  010-4752-2919
# 3          제주특별자치도 제주시 한림읍 금악리 625-2  010-9108-7003
# 4         제주특별자치도 제주시 애월읍 봉성리 3228-2   064-799-3340
# 5          제주특별자치도 제주시 한림읍 동명리 138-3   064-796-4473
#
#                                          description  \
# 0  죄송한 말씀을 드립니다.\n동물을 무서워하거나 거부감이 있으신 분들은\n방문하시기전...
# 1  부담없이 맛나게 드실수있는 건강한 집밥\n오전 11시영업시작 재료소진시 까지\n메뉴...
# 2  [숙소 정보]\n- 주소 : 제주시 애월읍 어림비로 376\n- 체크인/체크아웃 시...
# 3  1)제주도 최초 황칠오메기떡입니다. 홈쇼핑이나 택배판매로만 판매했던 황칠오메기떡을 ...
# 4  돈까스와 국수를 함께 즐길 수 있는 녹근로33\n\n네덜란드산 고다치즈를 활용한 라...
# 5  성게알, 전복, 게, 새우, 홍합, 문어 등 다양한 해산물과 콩나물, 미나리, 버섯...
#
#                                               images  \
# 0  [{'type': 'DRT', 'groupName': '기본 정보', 'number...
# 1  [{'type': 'DRT', 'groupName': '기본 정보', 'number...
# 2  [{'type': 'DRT', 'groupName': '기본 정보', 'number...
# 3  [{'type': 'DRT', 'groupName': '기본 정보', 'number...
# 4  [{'type': 'DRT', 'groupName': '기본 정보', 'number...
# 5  [{'type': 'DRT', 'groupName': '기본 정보', 'number...
#
#                                             imageURL     categories  \
# 0  https://ldb-phinf.pstatic.net/20211208_235/163...     [음식점, 브런치]
# 1  https://ldb-phinf.pstatic.net/20220611_190/165...      [음식점, 한식]
# 2  https://ldb-phinf.pstatic.net/20211027_198/163...  [음식점, 카페,디저트]
# 3  https://ldb-phinf.pstatic.net/20210406_232/161...  [카페,디저트, 떡카페]
# 4  https://ldb-phinf.pstatic.net/20190704_291/156...      [일식, 돈가스]
# 5  https://ldb-phinf.pstatic.net/20170523_138/149...  [한식, 해물,생선요리]
#
#                                          bizhourInfo  \
# 0  토요일 10:00~17:00 매주 화요일 휴무, 매월 마지막주 화/수 이틀 휴무 |...
# 1                                               None
# 2  일요일 10:00~18:00 | 월요일 10:00~18:00 | 토요일 10:00~...
# 3                                               None
# 4  금요일 11:00~15:45 | 화요일 11:00~15:45 | 월요일 11:00~...
# 5  토요일 09:00~21:00 (마지막주문 20:00) | 금요일 09:00~21:0...
#
#                                                menus  reviewCount
# 0  [{'name': '커피', 'price': '7,000원', 'isRecommen...          180
# 1                                               None            5
# 2  [{'name': '딸기라떼', 'price': '5,000원', 'isRecomm...           92
# 3  [{'name': '오메기떡', 'price': '1,000원', 'isRecomm...            0
# 4  [{'name': '라클렛돈까스', 'price': '16,000원', 'isRec...          147
# 5  [{'name': '갈치조림 대', 'price': '88,000원', 'isRec...          450

# %%
# images 테이블
images_list = []
for i in range(len(place_info)):
    for j in range(len(place_info[i]['images'])):
        place_info[i]['images'][j]['bus_id'] = place_info[i]['id']
    images_list.append(place_info[i]['images'])

df = pd.DataFrame(images_list[0])

for i in range(1,len(images_list)):
    df = pd.concat([df,pd.DataFrame(images_list[i])])

df = df.reset_index(drop=True)[['bus_id','number','url','modDate']]
df
# Out:
#         bus_id  number                                                url  \
# 0   1633977299       1  https://ldb-phinf.pstatic.net/20211208_235/163...
# 1   1633977299       2  https://ldb-phinf.pstatic.net/20220604_223/165...
# 2   1633977299       3  https://ldb-phinf.pstatic.net/20220604_10/1654...
# 3   1633977299       4  https://ldb-phinf.pstatic.net/20220604_223/165...
# 4   1633977299       5  https://ldb-phinf.pstatic.net/20220321_140/164...
# ..         ...     ...                                                ...
# 86    19873713       7  https://ldb-phinf.pstatic.net/20181127_223/154...
# 87    19873713       8  https://ldb-phinf.pstatic.net/20181127_287/154...
# 88    19873713       9  https://ldb-phinf.pstatic.net/20191113_240/157...
# 89    19873713      10  https://ldb-phinf.pstatic.net/20191113_194/157...
# 90    19873713      11  https://ldb-phinf.pstatic.net/20191113_152/157...
#
#                 modDate
# 0   2022-06-04 14:21:05
# 1   2022-06-04 14:21:05
# 2   2022-06-04 14:21:05
# 3   2022-06-04 14:21:05
# 4   2022-06-04 14:21:05
# ..                  ...
# 86  2020-09-29 04:11:57
# 87  2020-09-29 04:11:57
# 88  2020-09-29 04:11:57
# 89  2020-09-29 04:11:57
# 90  2020-09-29 04:11:57
#
# [91 rows x 4 columns]

# %%
# menus
menus = pd.DataFrame(place_profile['menus'][0])
menus['bus_id'] = place_profile['id'][0]

for i in range(1,len(place_profile)):
    df = pd.DataFrame(place_profile['menus'][i])
    df['bus_id'] = place_profile['id'][i]
    menus = pd.concat([menus,df])

menus = menus[['bus_id','name','price']].reset_index(drop=True)
menus
# Out:
#         bus_id       name     price
# 0   1633977299         커피    7,000원
# 1   1633977299     조식플레이트   19,000원
# 2   1633977299       착즙쥬스    8,000원
# 3   1633977299     프렌치토스트   15,000원
# 4   1449299326       딸기라떼    5,000원
# 5   1449299326  감귤요거트 스무디    5,000원
# 6   1449299326      한라봉주스    6,000원
# 7   1449299326     한라봉에이드    5,000원
# 8   1449299326      청귤에이드    5,000원
# 9   1449299326   개역(미숫가루)    5,000원
# 10  1449299326       어묵우동    6,000원
# 11  1449299326    햄/새우볶음밥    7,000원
# 12  1449299326       오메기떡    3,000원
# 13  1051333889       오메기떡    1,000원
# 14   933405444     라클렛돈까스   16,000원
# 15   933405444     녹근로돈까스   11,000원
# 16   933405444       고기국수    8,000원
# 17   933405444       비빔국수    8,000원
# 18    19873713     갈치조림 대   88,000원
# 19    19873713      해물탕 대   75,000원
# 20    19873713      통갈치조림  190,000원
# 21    19873713         소주    5,000원
# 22    19873713         맥주    5,000원
# 23    19873713     갈치조림 중   78,000원
# 24    19873713     갈치조림 소   58,000원
# 25    19873713      해물탕 중   65,000원
# 26    19873713      해물탕 소   50,000원

# %%
# 식당 기본 상세정보
place_default_profile = place_profile[['id','name','x','y','fullAddress','phone','description','imageURL','bizhourInfo','reviewCount']]
place_default_profile
# Out:
#            id      name           x          y  \
# 0  1633977299        조식  126.333206  33.410580
# 1  1439356450      어음밥집  126.339234  33.401998
# 2  1449299326  어음분교1963  126.338462  33.403274
# 3  1051333889    한라종합식품  126.318430  33.364895
# 4   933405444     녹근로33  126.314390  33.415685
# 5    19873713      만민식당  126.284252  33.383905
#
#                          fullAddress          phone  \
# 0         제주특별자치도 제주시 애월읍 어음리 3459-1
# 1         제주특별자치도 제주시 애월읍 어음리 2949-4   064-799-0788
# 2  제주특별자치도 제주시 애월읍 어음리 2922 어음분교1963  010-4752-2919
# 3          제주특별자치도 제주시 한림읍 금악리 625-2  010-9108-7003
# 4         제주특별자치도 제주시 애월읍 봉성리 3228-2   064-799-3340
# 5          제주특별자치도 제주시 한림읍 동명리 138-3   064-796-4473
#
#                                          description  \
# 0  죄송한 말씀을 드립니다.\n동물을 무서워하거나 거부감이 있으신 분들은\n방문하시기전...
# 1  부담없이 맛나게 드실수있는 건강한 집밥\n오전 11시영업시작 재료소진시 까지\n메뉴...
# 2  [숙소 정보]\n- 주소 : 제주시 애월읍 어림비로 376\n- 체크인/체크아웃 시...
# 3  1)제주도 최초 황칠오메기떡입니다. 홈쇼핑이나 택배판매로만 판매했던 황칠오메기떡을 ...
# 4  돈까스와 국수를 함께 즐길 수 있는 녹근로33\n\n네덜란드산 고다치즈를 활용한 라...
# 5  성게알, 전복, 게, 새우, 홍합, 문어 등 다양한 해산물과 콩나물, 미나리, 버섯...
#
#                                             imageURL  \
# 0  https://ldb-phinf.pstatic.net/20211208_235/163...
# 1  https://ldb-phinf.pstatic.net/20220611_190/165...
# 2  https://ldb-phinf.pstatic.net/20211027_198/163...
# 3  https://ldb-phinf.pstatic.net/20210406_232/161...
# 4  https://ldb-phinf.pstatic.net/20190704_291/156...
# 5  https://ldb-phinf.pstatic.net/20170523_138/149...
#
#                                          bizhourInfo  reviewCount
# 0  토요일 10:00~17:00 매주 화요일 휴무, 매월 마지막주 화/수 이틀 휴무 |...          180
# 1                                               None            5
# 2  일요일 10:00~18:00 | 월요일 10:00~18:00 | 토요일 10:00~...           92
# 3                                               None            0
# 4  금요일 11:00~15:45 | 화요일 11:00~15:45 | 월요일 11:00~...          147
# 5  토요일 09:00~21:00 (마지막주문 20:00) | 금요일 09:00~21:0...          450

# %%
import pymysql

place_test = pd.DataFrame(place_info)[['id','name','x','y','fullAddress']]

db = pymysql.connect(host='127.0.0.1',port=3306,user='root',passwd='1234',db='testdb',charset='utf8')

# %%
cursor = db.cursor()

sql = """
    CREATE TABLE IF NOT EXISTS place_info (
        id INT NOT NULL AUTO_INCREMENT,
        name VARCHAR(40) NOT NULL,
        x_position FLOAT,
        y_position FLOAT,
        PRIMARY KEY(id)
    )
"""
cursor.execute(sql)

cursor.execute("SHOW TABLES")

# cursor.close()
# Out:
# 4

# %%
for _, row in place_profile.iterrows():
    # print(row)
    sql  = f"""
        INSERT INTO place_info (name,x_position,y_position) VALUES ({row['id']},{row['x']},{row['y']})
        """
    print(sql)
    cursor.execute(sql)

db.commit()
# Out:
#         INSERT INTO place_info (name,x_position,y_position) VALUES (1633977299,126.3332056,33.4105799)
#
#
#         INSERT INTO place_info (name,x_position,y_position) VALUES (1439356450,126.3392341,33.4019981)
#
#
#         INSERT INTO place_info (name,x_position,y_position) VALUES (1449299326,126.33846166500638,33.40327431533632)
#
#
#         INSERT INTO place_info (name,x_position,y_position) VALUES (1051333889,126.31842982221268,33.364894947887976)
#
#
#         INSERT INTO place_info (name,x_position,y_position) VALUES (933405444,126.3143903,33.415685)
#
#
#         INSERT INTO place_info (name,x_position,y_position) VALUES (19873713,126.28425203203561,33.383904880598955)
