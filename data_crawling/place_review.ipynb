# %%
import requests
from master import headers
import json
import pandas as pd

url = "https://pcmap-api.place.naver.com/graphql"

# headers = {'User-Agent' : '개인 user-agent', 'Content-Type': 'application/json', 'accept': '*/*', 'accept-encoding': 'gzip, deflate, br', 'accept-language': 'ko'}
headers['Content-Type'] = "application/json"
headers['accept'] = '*/*'
headers['accept-encoding'] = 'gzip, deflate, br'
headers['accept-language'] = 'ko'
      
payload = [

{
        
        "operationName" : "getVisitorReviewPhotosInVisitorReviewTab",
        
        "variables" : {
            "businessId" : "601999582",
            "businessType": "restaurant",
            "display" : 20,
            "page":1
        },
        
        "query" : "query getVisitorReviewPhotosInVisitorReviewTab($businessId: String!, $businessType: String, $page: Int, $display: Int, $theme: String, $item: String) {\n  visitorReviews(input: {businessId: $businessId, businessType: $businessType, page: $page, display: $display, theme: $theme, item: $item, isPhotoUsed: true}) {\n    items {\n      id\n      rating\n      author {\n        id\n        nickname\n        from\n        imageUrl\n        objectId\n        url\n        __typename\n      }\n      body\n      thumbnail\n      media {\n        type\n        thumbnail\n        __typename\n      }\n      tags\n      status\n      visited\n      originType\n      item {\n        name\n        code\n        options\n        __typename\n      }\n      businessName\n      isFollowing\n      visitCount\n      votedKeywords {\n        code\n        iconUrl\n        iconCode\n        displayName\n        __typename\n      }\n      __typename\n    }\n    starDistribution {\n      score\n      count\n      __typename\n    }\n    hideProductSelectBox\n    total\n    __typename\n  }\n}\n",
    
    },

    {
      "operationName" : "getVisitorReviewStats",

      "query": "query getVisitorReviewStats($id: String, $itemId: String, $businessType: String = \"place\") {\n  visitorReviewStats(input: {businessId: $id, itemId: $itemId, businessType: $businessType}) {\n    id\n    name\n    apolloCacheId\n    review {\n      avgRating\n      totalCount\n      scores {\n        count\n        score\n        __typename\n      }\n      starDistribution {\n        count\n        score\n        __typename\n      }\n      imageReviewCount\n      authorCount\n      maxSingleReviewScoreCount\n      maxScoreWithMaxCount\n      __typename\n    }\n    analysis {\n      themes {\n        code\n        label\n        count\n        __typename\n      }\n      menus {\n        label\n        count\n        __typename\n      }\n      votedKeyword {\n        totalCount\n        reviewCount\n        userCount\n        details {\n          category\n          code\n          iconUrl\n          iconCode\n          displayName\n          count\n          previousRank\n          __typename\n        }\n        __typename\n      }\n      __typename\n    }\n    visitorReviewsTotal\n    ratingReviewsTotal\n    __typename\n  }\n}\n",

    "variables": {"businessType": "restaurant", "id": "601999582"},
    "businessType": "restaurant",
    "id": "601999582"
    },
] 


res = requests.post(headers=headers, url=url, data=json.dumps(payload))

# pd.DataFrame(res.json())
json_result = json.loads(res.text)
# json_result

json_result
# Out:
# [{'data': {'visitorReviews': {'items': [{'id': '6301bd7b051d38933d0cdd89',
#       'rating': None,
#       'author': {'id': '6fxDI',
#        'nickname': 'Jihyuniya',
#        'from': 'NAVER',
#        'imageUrl': None,
#        'objectId': '5ea570a98f87a842bc92226c',
#        'url': 'https://m.place.naver.com/my/5ea570a98f87a842bc92226c/review?v=2',
#        '__typename': 'VisitorReviewAuthor'},
#       'body': '국물이 진짜 맛나요',
#       'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4

#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/beating_heart20220119222223.png',
#         'iconCode': 'beating_heart',
#         'displayName': '친절해요',
#         '__typename': 'VisitorReviewVotedKeywords'}],
#       '__typename': 'VisitorReview'},
#      {'id': '62ef3e8b1bcfe28e3cfd10f6',
#       'rating': None,
#       'author': {'id': 'bgv3d',
#        'nickname': '오디랑',
#        'from': 'NAVER',
#        'imageUrl': 'https://phinf.pstatic.net/contact/20200601_246/1590974742778BHyxf_PNG/profileImage.png',
#        'objectId': '5d91659b8f87a842bcbe3771',
#        'url': 'https://m.place.naver.com/my/5d91659b8f87a842bcbe3771/review?v=2',
#        '__typename': 'VisitorReviewAuthor'},
#       'body': '국물이 넘 진하고 맛나요 옆에 카페 초입까지 줄이 있었는데 30분 기다려 먹었어요 ',
#       'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4MDdfMTI4/MDAxNjU5ODQ2MjQ5OTY0.sJR9S3Sid_zfnJT5ii8enClLc_7zkSJDrG8zemD2pbUg.cf8S_op5hdnHubFAbdxS9Mit9s2QHgHfzEKG_ob_XG8g.JPEG/upload_c41d062c77eeea559dab98da90ae129b.jpeg',
#       'media': [{'type': 'image',
#         'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4MDdfMTI4/MDAxNjU5ODQ2MjQ5OTY0.sJR9S3Sid_zfnJT5ii8enClLc_7zkSJDrG8zemD2pbUg.cf8S_op5hdnHubFAbdxS9Mit9s2QHgHfzEKG_ob_XG8g.JPEG/upload_c41d062c77eeea559dab98da90ae129b.jpeg',
#         '__typename': 'VisitorReviewMedia'}],
#       'tags': None,
#       'status': 'published',
#       'visited': '8.7.일',
#       'originType': '영수증',
#       'item': None,
#       'businessName': '태평소국밥',
#       'isFollowing': None,
#       'visitCount': 1,
#       'votedKeywords': [{'code': 'food_good',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/face_savoring_food20220119222022.png',
#         'iconCode': 'face_savoring_food',
#         'displayName': '음식이 맛있어요',
#         '__typename': 'VisitorReviewVotedKeywords'},
#        {'code': 'fresh',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/leaf20220119222023.png',
#         'iconCode': 'leaf',
#         'displayName': '재료가 신선해요',
#         '__typename': 'VisitorReviewVotedKeywords'},
#        {'code': 'large',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/steamed_rice20220119222024.png',
#         'iconCode': 'steamed_rice',
#         'displayName': '양이 많아요',
#         '__typename': 'VisitorReviewVotedKeywords'},
#        {'code': 'price_cheap',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/coin20220119222025.png',
#         'iconCode': 'coin',
#         'displayName': '가성비가 좋아요',
#         '__typename': 'VisitorReviewVotedKeywords'}],
#       '__typename': 'VisitorReview'},
#      {'id': '62ef21faa2b3c0a43c6fb7b9',
#       'rating': None,
#       'author': {'id': '9I9Ws',
#        'nickname': 'kkomi80',
#        'from': 'NAVER',
#        'imageUrl': 'https://phinf.pstatic.net/contact/20171117_300/1510884950233R2UlD_PNG/image.png',
#        'objectId': '5dd1d4b48f87a842bcc320fb',
#        'url': 'https://m.place.naver.com/my/5dd1d4b48f87a842bcc320fb/review?v=2',
#        '__typename': 'VisitorReviewAuthor'},
#       'body': '굿굿',
#       'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4MDdfMTg4/MDAxNjU5ODM4OTU4NTk2._mAyqqJtr__zl59WP7IiO3jJcpNA_uL3OwwFFzfWRoAg.WtR6-3NV4QfUV7SlhAouw074X3leEc-cLaQFx2hbweUg.JPEG/upload_7ba21e403c33289ab72557aac88c94cc.jpg',
#       'media': [{'type': 'image',
#         'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4MDdfMTg4/MDAxNjU5ODM4OTU4NTk2._mAyqqJtr__zl59WP7IiO3jJcpNA_uL3OwwFFzfWRoAg.WtR6-3NV4QfUV7SlhAouw074X3leEc-cLaQFx2hbweUg.JPEG/upload_7ba21e403c33289ab72557aac88c94cc.jpg',
#         '__typename': 'VisitorReviewMedia'}],
#       'tags': None,
#       'status': 'published',
#       'visited': '8.7.일',
#       'originType': '영수증',
#       'item': None,
#       'businessName': '태평소국밥',
#       'isFollowing': None,
#       'visitCount': 6,
#       'votedKeywords': [{'code': 'food_good',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/face_savoring_food20220119222022.png',
#         'iconCode': 'face_savoring_food',
#         'displayName': '음식이 맛있어요',
#         '__typename': 'VisitorReviewVotedKeywords'},
#        {'code': 'price_cheap',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/coin20220119222025.png',
#         'iconCode': 'coin',
#         'displayName': '가성비가 좋아요',
#         '__typename': 'VisitorReviewVotedKeywords'},
#        {'code': 'eat_alone',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/rice_ball20220119222026.png',
#         'iconCode': 'rice_ball',
#         'displayName': '혼밥하기 좋아요',
#         '__typename': 'VisitorReviewVotedKeywords'}],
#       '__typename': 'VisitorReview'},
#      {'id': '62edfffcf136a46fc1e5212c',
#       'rating': None,
#       'author': {'id': '22QuC',
#        'nickname': 'threerdsky',
#        'from': 'NAVER',
#        'imageUrl': None,
#        'objectId': '5c08a3a401160fcde2ba99a1',
#        'url': 'https://m.place.naver.com/my/5c08a3a401160fcde2ba99a1/review?v=2',
#        '__typename': 'VisitorReviewAuthor'},
#       'body': '',
#       'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4MDZfMTg4/MDAxNjU5NzY0NzI4MTk0.cbI3fuud8Ce44NU4MXHP8xOiPqjgYCBLpVcEv1sHu-cg.6R77MvUfOelV77ARUdeUntW1LLgmU8VJrhQ0L74PW4Qg.JPEG/upload_11ecbd57a81079518a24611368c894e9.jpg',
#       'media': [{'type': 'image',
#         'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4MDZfMTg4/MDAxNjU5NzY0NzI4MTk0.cbI3fuud8Ce44NU4MXHP8xOiPqjgYCBLpVcEv1sHu-cg.6R77MvUfOelV77ARUdeUntW1LLgmU8VJrhQ0L74PW4Qg.JPEG/upload_11ecbd57a81079518a24611368c894e9.jpg',
#         '__typename': 'VisitorReviewMedia'}],
#       'tags': None,
#       'status': 'published',
#       'visited': '8.6.토',
#       'originType': '영수증',
#       'item': None,
#       'businessName': '태평소국밥',
#       'isFollowing': None,
#       'visitCount': 1,
#       'votedKeywords': [{'code': 'food_good',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/face_savoring_food20220119222022.png',
#         'iconCode': 'face_savoring_food',
#         'displayName': '음식이 맛있어요',
#         '__typename': 'VisitorReviewVotedKeywords'}],
#       '__typename': 'VisitorReview'},
#      {'id': '62ed4757a92c68a8f805402a',
#       'rating': None,
#       'author': {'id': '8p12p',
#        'nickname': '푸르릉하마',
#        'from': 'NAVER',
#        'imageUrl': None,
#        'objectId': '608366537fcc3681ef626d55',
#        'url': 'https://m.place.naver.com/my/608366537fcc3681ef626d55/review?v=2',
#        '__typename': 'VisitorReviewAuthor'},
#       'body': '굳굳~~"~',
#       'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4MDZfMjg3/MDAxNjU5NzE3NDYwMzAy.p_7NHUZisOeOE9DZV9ORKlBP52h-XwZkIAwpLNjnlOgg.orqf3iVJxNykdmIKuabk_RMHng2STmNNAg1fBgdzi9og.JPEG/upload_6dec89bfb92543807974b8a1fd711255.jpg',
#       'media': [{'type': 'image',
#         'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4MDZfMjg3/MDAxNjU5NzE3NDYwMzAy.p_7NHUZisOeOE9DZV9ORKlBP52h-XwZkIAwpLNjnlOgg.orqf3iVJxNykdmIKuabk_RMHng2STmNNAg1fBgdzi9og.JPEG/upload_6dec89bfb92543807974b8a1fd711255.jpg',
#         '__typename': 'VisitorReviewMedia'}],
#       'tags': None,
#       'status': 'published',
#       'visited': '8.6.토',
#       'originType': '영수증',
#       'item': None,
#       'businessName': '태평소국밥',
#       'isFollowing': None,
#       'visitCount': 1,
#       'votedKeywords': [{'code': 'food_good',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/face_savoring_food20220119222022.png',
#         'iconCode': 'face_savoring_food',
#         'displayName': '음식이 맛있어요',
#         '__typename': 'VisitorReviewVotedKeywords'},
#        {'code': 'fresh',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/leaf20220119222023.png',
#         'iconCode': 'leaf',
#         'displayName': '재료가 신선해요',
#         '__typename': 'VisitorReviewVotedKeywords'},
#        {'code': 'price_cheap',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/coin20220119222025.png',
#         'iconCode': 'coin',
#         'displayName': '가성비가 좋아요',
#         '__typename': 'VisitorReviewVotedKeywords'}],
#       '__typename': 'VisitorReview'},
#      {'id': '62ec9550b3846d97a82ac359',
#       'rating': None,
#       'author': {'id': '3hRcH',
#        'nickname': 'giy****',
#        'from': 'NAVER',
#        'imageUrl': None,
#        'objectId': '5e3fa23e8f87a842bc458c2d',
#        'url': 'https://m.place.naver.com/my/5e3fa23e8f87a842bc458c2d/review?v=2',
#        '__typename': 'VisitorReviewAuthor'},
#       'body': '맛있어요',
#       'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4MDVfMTE5/MDAxNjU5NjcxODgwNTg5.1kNSs9eZ2wnRzqy-MKsFKUao1P5__yUkqBQvrZK4B40g.U88B6pQW8wpfyaKNl5kh5CU2qN5VYygCXCl7AYk99wMg.JPEG/upload_ef6721ff5c361012b4ee8fbcd2255e8d.jpg',
#       'media': [{'type': 'image',
#         'thumbnail': 'https://pup-review-phinf.pstatic.net/MjAyMjA4MDVfMTE5/MDAxNjU5NjcxODgwNTg5.1kNSs9eZ2wnRzqy-MKsFKUao1P5__yUkqBQvrZK4B40g.U88B6pQW8wpfyaKNl5kh5CU2qN5VYygCXCl7AYk99wMg.JPEG/upload_ef6721ff5c361012b4ee8fbcd2255e8d.jpg',
#         '__typename': 'VisitorReviewMedia'}],
#       'tags': None,
#       'status': 'published',
#       'visited': '8.5.금',
#       'originType': '영수증',
#       'item': None,
#       'businessName': '태평소국밥',
#       'isFollowing': None,
#       'visitCount': 1,
#       'votedKeywords': [{'code': 'food_good',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/face_savoring_food20220119222022.png',
#         'iconCode': 'face_savoring_food',
#         'displayName': '음식이 맛있어요',
#         '__typename': 'VisitorReviewVotedKeywords'}],
#       '__typename': 'VisitorReview'}],
#     'starDistribution': None,
#     'hideProductSelectBox': True,
#     'total': 416,
#     '__typename': 'VisitorReviewsResult'}}},
#  {'data': {'visitorReviewStats': {'id': 601999582,
#     'name': None,
#     'apolloCacheId': None,
#     'review': {'avgRating': 4.45,
#      'totalCount': 5213,
#      'scores': [{'count': 1550,
#        'score': None,
#        '__typename': 'VisitorReviewScore'},
#       {'count': 139, 'score': None, '__typename': 'VisitorReviewScore'},
#       {'count': 16, 'score': None, '__typename': 'VisitorReviewScore'},
#       {'count': 348, 'score': None, '__typename': 'VisitorReviewScore'},
#       {'count': 1, 'score': None, '__typename': 'VisitorReviewScore'},
#       {'count': 8, 'score': None, '__typename': 'VisitorReviewScore'},
#       {'count': 28, 'score': None, '__typename': 'VisitorReviewScore'},
#       {'count': 6, 'score': None, '__typename': 'VisitorReviewScore'},
#       {'count': 718, 'score': None, '__typename': 'VisitorReviewScore'},
#       {'count': 7, 'score': None, '__typename': 'VisitorReviewScore'},
#       {'count': 150, 'score': None, '__typename': 'VisitorReviewScore'}],
#      'starDistribution': [{'count': None,
#        'score': '0.0',
#        '__typename': 'VisitorReviewScore'},
#       {'count': None, 'score': '0.5', '__typename': 'VisitorReviewScore'},
#       {'count': None, 'score': '1.0', '__typename': 'VisitorReviewScore'},
#       {'count': None, 'score': '1.5', '__typename': 'VisitorReviewScore'},
#       {'count': None, 'score': '2.0', '__typename': 'VisitorReviewScore'},
#       {'count': None, 'score': '2.5', '__typename': 'VisitorReviewScore'},
#       {'count': None, 'score': '3.0', '__typename': 'VisitorReviewScore'},
#       {'count': None, 'score': '3.5', '__typename': 'VisitorReviewScore'},
#       {'count': None, 'score': '4.0', '__typename': 'VisitorReviewScore'},
#       {'count': None, 'score': '4.5', '__typename': 'VisitorReviewScore'},
#       {'count': None, 'score': '5.0', '__typename': 'VisitorReviewScore'}],
#      'imageReviewCount': 416,
#      'authorCount': 3420,
#      'maxSingleReviewScoreCount': 1550,
#      'maxScoreWithMaxCount': '5.0',
#      '__typename': 'VisitorReviewStats'},
#     'analysis': {'themes': [{'code': 'taste',
#        'label': '맛',
#        'count': 868,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'total',
#        'label': '만족도',
#        'count': 482,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'amount',
#        'label': '음식량',
#        'count': 72,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'service',
#        'label': '서비스',
#        'count': 65,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'price',
#        'label': '가격',
#        'count': 47,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'waitingtime',
#        'label': '대기시간',
#        'count': 44,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'parking',
#        'label': '주차',
#        'count': 10,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'cleanliness',
#        'label': '청결도',
#        'count': 8,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'delivery',
#        'label': '배달',
#        'count': 5,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'mood',
#        'label': '분위기',
#        'count': 5,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'menu',
#        'label': '메뉴',
#        'count': 4,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'location',
#        'label': '위치',
#        'count': 4,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'purpose',
#        'label': '목적',
#        'count': 3,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'},
#       {'code': 'covid19',
#        'label': '방역',
#        'count': 2,
#        '__typename': 'VisitorReviewStatsAnalysisThemes'}],
#      'menus': [{'label': '국밥',
#        'count': 286,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '육회',
#        'count': 142,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '소고기국밥',
#        'count': 127,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '내장탕',
#        'count': 102,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '고기',
#        'count': 77,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '갈비',
#        'count': 45,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '소고기',
#        'count': 42,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '갈비찜',
#        'count': 42,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '깍두기',
#        'count': 26,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '소고기무국',
#        'count': 20,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '갈비탕',
#        'count': 20,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '매운갈비',
#        'count': 18,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '매운갈비찜',
#        'count': 17,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '따로국밥',
#        'count': 15,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '수육',
#        'count': 12,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '소갈비',
#        'count': 11,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '소갈비찜',
#        'count': 10,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '소내장탕',
#        'count': 8,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '매운소갈비찜',
#        'count': 7,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '소머리국밥',
#        'count': 6,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '한우',
#        'count': 6,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '내장국밥',
#        'count': 5,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '생고기',
#        'count': 3,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '소머리수육',
#        'count': 3,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '한우국밥',
#        'count': 2,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '뭉티기',
#        'count': 2,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '한우육사시미',
#        'count': 2,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '해장국',
#        'count': 2,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '소고기국',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '밥집',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '스테이크',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '머리고기',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '육포',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '가정식백반',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '두부',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '설렁탕',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '등갈비',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '배추김치',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '국수',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '고기국수',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '칼국수',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '떡볶이',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'},
#       {'label': '돼지국밥',
#        'count': 1,
#        '__typename': 'VisitorReviewStatsAnalysisMenus'}],
#      'votedKeyword': {'totalCount': 4235,
#       'reviewCount': 2361,
#       'userCount': 1915,
#       'details': [{'category': None,
#         'code': 'food_good',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/face_savoring_food20220119222022.png',
#         'iconCode': 'face_savoring_food',
#         'displayName': '음식이 맛있어요',
#         'count': 1807,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'price_cheap',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/coin20220119222025.png',
#         'iconCode': 'coin',
#         'displayName': '가성비가 좋아요',
#         'count': 467,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'large',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/steamed_rice20220119222024.png',
#         'iconCode': 'steamed_rice',
#         'displayName': '양이 많아요',
#         'count': 382,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'fresh',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/leaf20220119222023.png',
#         'iconCode': 'leaf',
#         'displayName': '재료가 신선해요',
#         'count': 321,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'spacious',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/eyes20220119222026.png',
#         'iconCode': 'eyes',
#         'displayName': '매장이 넓어요',
#         'count': 267,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'eat_alone',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/rice_ball20220119222026.png',
#         'iconCode': 'rice_ball',
#         'displayName': '혼밥하기 좋아요',
#         'count': 235,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'kind',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/beating_heart20220119222223.png',
#         'iconCode': 'beating_heart',
#         'displayName': '친절해요',
#         'count': 224,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'special_menu',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/cook20220119222024.png',
#         'iconCode': 'cook',
#         'displayName': '특별한 메뉴가 있어요',
#         'count': 219,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'parking_easy',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/park_sign20220119222222.png',
#         'iconCode': 'park_sign',
#         'displayName': '주차하기 편해요',
#         'count': 141,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'store_clean',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/sparkles20220119222028.png',
#         'iconCode': 'sparkles',
#         'displayName': '매장이 청결해요',
#         'count': 67,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'together',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/busts_in_silhouette20220119222027.png',
#         'iconCode': 'busts_in_silhouette',
#         'displayName': '단체모임 하기 좋아요',
#         'count': 45,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'toilet_clean',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/restroom20220119222222.png',
#         'iconCode': 'restroom',
#         'displayName': '화장실이 깨끗해요',
#         'count': 20,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'special_day',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/bouquet20220119222223.png',
#         'iconCode': 'bouquet',
#         'displayName': '특별한 날 가기 좋아요',
#         'count': 19,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'interior_cool',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/couch_and_lamp20220119222025.png',
#         'iconCode': 'couch_and_lamp',
#         'displayName': '인테리어가 멋져요',
#         'count': 11,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'},
#        {'category': None,
#         'code': 'view_good',
#         'iconUrl': 'https://ssl.pstatic.net/static/pup/emoji/framed_picture20220119222027.png',
#         'iconCode': 'framed_picture',
#         'displayName': '뷰가 좋아요',
#         'count': 10,
#         'previousRank': None,
#         '__typename': 'VisitorReviewStatsAnalysisVoteKeywordDetail'}],
#       '__typename': 'VisitorReviewStatsAnalysisVoteKeyword'},
#      '__typename': 'VisitorReviewStatsAnalysis'},
#     'visitorReviewsTotal': 5213,
#     'ratingReviewsTotal': 3154,
#     '__typename': 'VisitorReviewStatsResult'}}}]

# %%
df = pd.DataFrame(json_result[0]['data']['visitorReviews']['items'])

pd.DataFrame(json_result[1]['data']['visitorReviewStats'])[['id','review','analysis','visitorReviewsTotal','ratingReviewsTotal']]


# 리뷰 아이콘에 위치한 데이터
reviews = json_result[1]['data']['visitorReviewStats']['analysis']['themes']

# 식당 메뉴 정보
menus = json_result[1]['data']['visitorReviewStats']['analysis']['menus']

# rating 요약 정보 (이런 점이 좋았어요.)
ratings = json_result[1]['data']['visitorReviewStats']['analysis']['votedKeyword']['details']

json_result[1]['data']['visitorReviewStats']['analysis']['themes']

# %%
bus_id = ['601999582','20352555']


# 주소 파싱
for id in bus_id:
    r= requests.get(url=f'https://map.naver.com/v5/api/sites/summary/{id}?lang=ko',headers=headers)
    print(r.json()['phone'])
    print(r.json()['address'])
    print(r.json()['name'])
    print(r.json()['description'])
